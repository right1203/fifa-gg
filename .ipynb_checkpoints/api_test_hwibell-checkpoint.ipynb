# %%
import requests
import json

# %%
my_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2NvdW50X2lkIjoiNDUzMzA3MDE3IiwiYXV0aF9pZCI6IjIiLCJ0b2tlbl90eXBlIjoiQWNjZXNzVG9rZW4iLCJzZXJ2aWNlX2lkIjoiNDMwMDExNDgxIiwiWC1BcHAtUmF0ZS1MaW1pdCI6IjIwMDAwOjEwIiwibmJmIjoxNTcwODY0MTQ1LCJleHAiOjE2MzM5MzYxNDUsImlhdCI6MTU3MDg2NDE0NX0.zuPgSHe4L1Cr2GDufJcuASm6uKjLY1xrP3Y1gjr9mqA'

# %%
# 매치타입
header = {'Authorization':my_key}
matchtype_url = "https://static.api.nexon.co.kr/fifaonline4/latest/matchtype.json"
matchtype_res = requests.get(matchtype_url, headers = header)

if(matchtype_res.status_code == 200):
    matchtype_data = matchtype_res.json()
    print("매치타입코드 : " + str(matchtype_data[0]['matchtype']))
    print("매치타입 : " + str(matchtype_data[0]['desc']))
# Out:
# 매치타입코드 : 50
# 매치타입 : 공식경기

# %%
# 유저 정보

userinfo = {}
userinfo_params = {"nickname":"브라질"}
userinfo_url = 'https://api.nexon.co.kr/fifaonline4/v1.0/users?nickname=' + userinfo_params["nickname"]
header = {"Authorization":my_key}
userinfo_response = requests.get(userinfo_url, headers = header)

if(userinfo_response.status_code == 200):
    userinfo_data = userinfo_response.json()
    userinfo['accessId'] = userinfo_data["accessId"]
    userinfo['nickname'] = userinfo_data["nickname"]
    userinfo['level'] = userinfo_data["level"]
    print("고유식별자 : " + userinfo_data['accessId'])
    print("닉네임 : " + userinfo_data['nickname'])
    print("레벨 : " + str(userinfo_data['level']))
else:
    print("Error Code:" + userinfo_response.status_code)
    
userinfo['nickname']
# Out:
# 고유식별자 : 48d9ba8b58d39e8d7c7fea7c
# 닉네임 : 브라질
# 레벨 : 232
# '브라질'

# %%
# 최근 매치 기록

recentmatches_params = {"accessId":userinfo_data["accessId"], 'matchtype':matchtype_data[0]['matchtype'], 'offset':0, 'limit':20}
recentmatches_url = 'https://api.nexon.co.kr/fifaonline4/v1.0/users/{accessid}/matches?matchtype={matchtype}&offset={offset}&limit={limit}'.format(accessid=recentmatches_params["accessId"], matchtype=recentmatches_params['matchtype'], offset=recentmatches_params['offset'], limit=recentmatches_params['limit'] )
recentmatches_res = requests.get(recentmatches_url, headers=header)

if(recentmatches_res.status_code==200):
    recentmatches_data = recentmatches_res.json()
    print(recentmatches_data[0])
# Out:
# 5dd6eb20c2067fa059e5a3ed

# %%
len(recentmatches_data)
# Out:
# 20

# %%
# 매치 상세 기록
matchdetail = []
for matchid in recentmatches_data:
    matchdetail_url = 'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}'.format(matchid=matchid)
    matchdetail_res = requests.get(matchdetail_url, headers=header)
    if(matchdetail_res.status_code==200):
        matchdetail_data = matchdetail_res.json()
        matchdetail.append(matchdetail_data)

# %%
recent_winlose = []
recent_score = []
recent_against_score = []
goal_count = []
shoot_count = []
possession = []
pass_try = []
pass_success = []
dribble = []

for detail in matchdetail:
    if detail['matchInfo'][0]['nickname'] == userinfo_params["nickname"]:
        search_info = detail['matchInfo'][0]
        opponent_info = detail['matchInfo'][1]
    else:
        search_info = detail['matchInfo'][1]
        opponent_info = detail['matchInfo'][0]
    
    if search_info['matchDetail']['matchEndType'] == 0:
        recent_winlose.append(search_info['matchDetail']['matchResult'])
        
    elif search_info['matchDetail']['matchEndType'] == 1:
        recent_winlose.append('몰수승')
    else:
        recent_winlose.append('몰수패')
        
    recent_score.append(search_info['shoot']['goalTotal'])
    recent_against_score.append(opponent_info['shoot']['goalTotal'] + search_info['shoot']['ownGoal'])
    goal_count.append(search_info['shoot']['goalTotal'])
    shoot_count.append(search_info['shoot']['shootTotal'])
    possession.append(search_info['matchDetail']['possession'])
    pass_try.append(search_info['pass']['passTry'])
    pass_success.append(search_info['pass']['passSuccess'])
    dribble.append(search_info['matchDetail']['dribble'])

# %%
recent_score
# Out:
# [1, 2, 1, 3, 3, 3, 3, 0, 0, 0, 3, 2, 0, 2, 2, 1, 3, 3, 0, 1]

# %%
recent_against_score
# Out:
# [2, 1, 1, 3, 0, 2, 0, 7, 0, 1, 1, 1, 2, 3, 2, 2, 3, 0, 0, 0]

# %%
len(recent_against_score)
# Out:
# 20

# %%
print((recent_winlose.count('승') + recent_winlose.count('몰수승')) / len(recent_winlose))
print(sum(recent_score) / len(recent_score))
print(sum(recent_against_score) / len(recent_against_score))
print(sum(goal_count) / sum(shoot_count))
print(sum(possession) / len(possession))
print(f"{sum(pass_success)} / {sum(pass_try)} ({sum(pass_success) / sum(pass_try)})")
print(sum(dribble) / len(dribble))
# Out:
# 0.4
# 1.15
# 1.25
# 0.23469387755102042
# 53.1
# 1890 / 2083 (0.9073451752280365)
# 54.85

# %%
recent_winlose
# Out:
# ['무',
#  '패',
#  '몰수승',
#  '무',
#  '승',
#  '승',
#  '몰수승',
#  '승',
#  '무',
#  '승',
#  '패',
#  '패',
#  '승',
#  '패',
#  '패',
#  '무',
#  '무',
#  '패',
#  '승',
#  '패']

# %%
search_info['matchDetail']
# Out:
# {'seasonId': 201917,
#  'matchResult': '승',
#  'matchEndType': 0,
#  'systemPause': 0,
#  'foul': 1,
#  'injury': 0,
#  'redCards': 0,
#  'yellowCards': 0,
#  'dribble': 43,
#  'cornerKick': 1,
#  'possession': 54}

# %% [markdown]
# # MatchDetail

# %%
matchdetail[9]
# Out:
# {'matchId': '5db90499f3ad407211ec96cb',
#  'matchDate': '2019-10-30T12:43:48',
#  'matchType': 50,
#  'matchInfo': [{'accessId': 'efe0fd08ee38f05ab3f93104',
#    'nickname': '개인기모름',
#    'matchDetail': {'seasonId': 201917,
#     'matchResult': '패',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 2,
#     'injury': 1,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 49,
#     'cornerKick': 0,
#     'possession': 54},
#    'shoot': {'shootTotal': 3,
#     'effectiveShootTotal': 1,
#     'shootOutScore': 0,
#     'goalTotal': 1,
#     'goalTotalDisplay': 1,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 0,
#     'goalFreekick': 0,
#     'shootInPenalty': 2,
#     'goalInPenalty': 1,
#     'shootOutPenalty': 1,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 0,
#     'goalPenaltyKick': 0},
#    'shootDetail': [{'goalTime': 2900,
#      'x': 0.8886542916297913,
#      'y': 0.5014259815216064,
#      'type': 1,
#      'result': 3,
#      'assist': True,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778118,
#      'x': 0.8826776146888733,
#      'y': 0.3302481472492218,
#      'type': 1,
#      'result': 2,
#      'assist': False,
#      'hitPost': True,
#      'inPenalty': True},
#     {'goalTime': 16778679,
#      'x': 0.75989282131195,
#      'y': 0.5155675411224365,
#      'type': 1,
#      'result': 2,
#      'assist': True,
#      'hitPost': False,
#      'inPenalty': False}],
#    'pass': {'passTry': 129,
#     'passSuccess': 111,
#     'shortPassTry': 77,
#     'shortPassSuccess': 72,
#     'longPassTry': 6,
#     'longPassSuccess': 1,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 3,
#     'drivenGroundPassSuccess': 3,
#     'throughPassTry': 40,
#     'throughPassSuccess': 34,
#     'lobbedThroughPassTry': 3,
#     'lobbedThroughPassSuccess': 1},
#    'defence': {'blockTry': 9,
#     'blockSuccess': 0,
#     'tackleTry': 20,
#     'tackleSuccess': 8},
#    'player': [{'spId': 214001116,
#      'spPosition': 6,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 4,
#       'passSuccess': 3,
#       'block': 0,
#       'tackle': 2,
#       'spRating': 5.4}},
#     {'spId': 201001419,
#      'spPosition': 4,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 10,
#       'passSuccess': 10,
#       'block': 0,
#       'tackle': 1,
#       'spRating': 6.1}},
#     {'spId': 212193080,
#      'spPosition': 28,
#      'spGrade': 3,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 216194765,
#      'spPosition': 27,
#      'spGrade': 2,
#      'status': {'shoot': 1,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 10,
#       'passSuccess': 9,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 5.2}},
#     {'spId': 214195864,
#      'spPosition': 18,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 18,
#       'passSuccess': 18,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 7.3}},
#     {'spId': 501201042,
#      'spPosition': 3,
#      'spGrade': 6,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 15,
#       'passSuccess': 11,
#       'block': 0,
#       'tackle': 2,
#       'spRating': 6.5}},
#     {'spId': 210203747,
#      'spPosition': 28,
#      'spGrade': 3,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 201005984,
#      'spPosition': 28,
#      'spGrade': 2,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 211158023,
#      'spPosition': 23,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 294,
#       'passTry': 16,
#       'passSuccess': 13,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 5.8}},
#     {'spId': 300163705,
#      'spPosition': 0,
#      'spGrade': 8,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 7.3}},
#     {'spId': 210164859,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 207191189,
#      'spPosition': 28,
#      'spGrade': 2,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 210204884,
#      'spPosition': 7,
#      'spGrade': 3,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 2,
#       'passSuccess': 2,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 2.8}},
#     {'spId': 216215914,
#      'spPosition': 9,
#      'spGrade': 3,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 14,
#       'passSuccess': 14,
#       'block': 0,
#       'tackle': 1,
#       'spRating': 6.2}},
#     {'spId': 216222481,
#      'spPosition': 11,
#      'spGrade': 2,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 19,
#       'passSuccess': 16,
#       'block': 0,
#       'tackle': 2,
#       'spRating': 6.5}},
#     {'spId': 210230621,
#      'spPosition': 28,
#      'spGrade': 3,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 210231443,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 210231747,
#      'spPosition': 25,
#      'spGrade': 3,
#      'status': {'shoot': 2,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 1,
#       'dribble': 65,
#       'passTry': 18,
#       'passSuccess': 12,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 7.1}}]},
#   {'accessId': 'fea20699b60a4023ed6e0249',
#    'nickname': '대야미신사',
#    'matchDetail': {'seasonId': 201917,
#     'matchResult': '승',
#     'matchEndType': 0,
#     'systemPause': 0,
#     'foul': 0,
#     'injury': 0,
#     'redCards': 0,
#     'yellowCards': 0,
#     'dribble': 51,
#     'cornerKick': 0,
#     'possession': 46},
#    'shoot': {'shootTotal': 5,
#     'effectiveShootTotal': 4,
#     'shootOutScore': 0,
#     'goalTotal': 2,
#     'goalTotalDisplay': 2,
#     'ownGoal': 0,
#     'shootHeading': 0,
#     'goalHeading': 0,
#     'shootFreekick': 1,
#     'goalFreekick': 0,
#     'shootInPenalty': 3,
#     'goalInPenalty': 1,
#     'shootOutPenalty': 1,
#     'goalOutPenalty': 0,
#     'shootPenaltyKick': 1,
#     'goalPenaltyKick': 1},
#    'shootDetail': [{'goalTime': 16779454,
#      'x': 0.902687132358551,
#      'y': 0.3924496173858643,
#      'type': 2,
#      'result': 1,
#      'assist': True,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16779502,
#      'x': 0.9013394117355348,
#      'y': 0.4980932474136353,
#      'type': 1,
#      'result': 3,
#      'assist': False,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 1174,
#      'x': 0.8282949328422546,
#      'y': 0.416970431804657,
#      'type': 2,
#      'result': 2,
#      'assist': False,
#      'hitPost': False,
#      'inPenalty': False},
#     {'goalTime': 16778411,
#      'x': 0.9042693972587584,
#      'y': 0.4093583524227142,
#      'type': 1,
#      'result': 1,
#      'assist': False,
#      'hitPost': False,
#      'inPenalty': True},
#     {'goalTime': 16778430,
#      'x': 0.9071276187896729,
#      'y': 0.4574529826641083,
#      'type': 1,
#      'result': 3,
#      'assist': True,
#      'hitPost': False,
#      'inPenalty': True}],
#    'pass': {'passTry': 74,
#     'passSuccess': 67,
#     'shortPassTry': 51,
#     'shortPassSuccess': 49,
#     'longPassTry': 1,
#     'longPassSuccess': 0,
#     'bouncingLobPassTry': 0,
#     'bouncingLobPassSuccess': 0,
#     'drivenGroundPassTry': 0,
#     'drivenGroundPassSuccess': 0,
#     'throughPassTry': 21,
#     'throughPassSuccess': 18,
#     'lobbedThroughPassTry': 0,
#     'lobbedThroughPassSuccess': 0},
#    'defence': {'blockTry': 12,
#     'blockSuccess': 0,
#     'tackleTry': 7,
#     'tackleSuccess': 7},
#    'player': [{'spId': 214013038,
#      'spPosition': 6,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 5,
#       'passSuccess': 5,
#       'block': 0,
#       'tackle': 3,
#       'spRating': 7.2}},
#     {'spId': 214152729,
#      'spPosition': 4,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 5,
#       'passSuccess': 5,
#       'block': 0,
#       'tackle': 1,
#       'spRating': 6.8}},
#     {'spId': 210158023,
#      'spPosition': 21,
#      'spGrade': 1,
#      'status': {'shoot': 4,
#       'effectiveShoot': 3,
#       'assist': 0,
#       'goal': 2,
#       'dribble': 0,
#       'passTry': 9,
#       'passSuccess': 7,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 8.6}},
#     {'spId': 300176071,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 300186801,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 300199247,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 501199564,
#      'spPosition': 3,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 4,
#       'passSuccess': 4,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 6.5}},
#     {'spId': 300205186,
#      'spPosition': 28,
#      'spGrade': 0,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 300207557,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 300215181,
#      'spPosition': 28,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 300228702,
#      'spPosition': 13,
#      'spGrade': 7,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 1,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 9,
#       'passSuccess': 8,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 7.2}},
#     {'spId': 501230658,
#      'spPosition': 15,
#      'spGrade': 5,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 23,
#       'passTry': 11,
#       'passSuccess': 8,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 6.6}},
#     {'spId': 300231144,
#      'spPosition': 28,
#      'spGrade': 0,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 0,
#       'passSuccess': 0,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 0.0}},
#     {'spId': 214189332,
#      'spPosition': 7,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 7,
#       'passSuccess': 7,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 6.4}},
#     {'spId': 216189511,
#      'spPosition': 10,
#      'spGrade': 1,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 7,
#       'passSuccess': 7,
#       'block': 0,
#       'tackle': 3,
#       'spRating': 7.0}},
#     {'spId': 214190871,
#      'spPosition': 27,
#      'spGrade': 3,
#      'status': {'shoot': 1,
#       'effectiveShoot': 1,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 316,
#       'passTry': 5,
#       'passSuccess': 5,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 6.8}},
#     {'spId': 300192448,
#      'spPosition': 0,
#      'spGrade': 4,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 0,
#       'passTry': 3,
#       'passSuccess': 3,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 6.3}},
#     {'spId': 210194765,
#      'spPosition': 23,
#      'spGrade': 2,
#      'status': {'shoot': 0,
#       'effectiveShoot': 0,
#       'assist': 0,
#       'goal': 0,
#       'dribble': 203,
#       'passTry': 9,
#       'passSuccess': 8,
#       'block': 0,
#       'tackle': 0,
#       'spRating': 6.3}}]}]}
